# %% [markdown]
# # Upload Image2GPS Dataset to Hugging Face
#
# This notebook prepares the local `data/image2gps_dataset/` folder as a Hugging Face image dataset.
# The upload cells are intentionally commented out to prevent accidental uploads

# %%
# # Uncomment and run this cell if kernel is missing dependencies.
# %pip install datasets huggingface_hub
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Local Dataset Folder
#
# This expects notebook 1 to have generated train/validation folders with one `metadata.csv` per split.

# %%
import os

REPO_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..")) if os.path.basename(os.getcwd()) == "notebooks" else os.getcwd()
DATA_DIR = os.path.join(REPO_ROOT, "data", "image2gps_dataset")

print(DATA_DIR)
# Out:
# /Users/mhedlund/CIS5190/CIS-5190-Final-Project/data/image2gps_dataset

# %%
from datasets import load_dataset

dataset = load_dataset("imagefolder", data_dir=DATA_DIR)
dataset
# Out:
# ...
# Resolving data files:   0%|          | 0/252 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'Latitude', 'Longitude'],
#         num_rows: 1416
#     })
#     validation: Dataset({
#         features: ['image', 'Latitude', 'Longitude'],
#         num_rows: 251
#     })
# })

# %%
print(dataset)
print(dataset["train"][0])
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'Latitude', 'Longitude'],
#         num_rows: 1416
#     })
#     validation: Dataset({
#         features: ['image', 'Latitude', 'Longitude'],
#         num_rows: 251
#     })
# })
# {'image': <PIL.Image.Image image mode=RGB size=3024x4032 at 0x1424CAAB0>, 'Latitude': 39.95163055555556, 'Longitude': -75.19216944444445}

# %% [markdown]
# ## Login
#
# Login in terminal through hf auth login

# %% [markdown]
# ## Push Dataset

# %%
HF_DATASET_REPO_ID = "mhedlund/CIS5190IMG2GPS"
dataset.push_to_hub(HF_DATASET_REPO_ID)
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ...
# Creating parquet from Arrow format:   0%|          | 0/5 [00:00<?, ?ba/s]
# ...
